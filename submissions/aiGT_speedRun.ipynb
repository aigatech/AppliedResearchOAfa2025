# %% [markdown]
# <a href="https://colab.research.google.com/github/mooshroom-person/AppliedResearchOAfa2025/blob/main/aiGT_speedRun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle
from google.colab import files
files.upload()

# !mkdir ~/.kaggle

# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download jockeroika/human-bone-fractures-image-dataset
# !unzip human-bone-fractures-image-dataset.zip
# !pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
#      <input type="file" id="files-ed79d963-3b59-4ddc-ad72-9b422f2c7c6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed79d963-3b59-4ddc-ad72-9b422f2c7c6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n-cls.pt")  # build from YAML and transfer weights
# Out:
# ...
# Transferred 192/499 items from pretrained weights

# %%
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=train model=yolo11n.pt data="/content/datasets/hbfmid/bfd/data.yaml" epochs=100 imgsz=96
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO("yolo11n.pt")  # load an official model
model = YOLO("path/to/best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category

# %%
# Out:
# mv: cannot stat '/content/Human Bone Fractures Multi-modal Image Dataset (HBFMID)': No such file or directory
